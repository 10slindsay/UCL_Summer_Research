# %%
import matplotlib.pyplot as plt

# %matplotlib inline
# magic function

# %%
import numpy as np
import healpy as hp

# %%
NSIDE = 32
print(
    "Approximate resolution at NSIDE {} is {:.2} deg".format(
        NSIDE, hp.nside2resol(NSIDE, arcmin=True) / 60
    )
)

#NSIDE defines the resolution of the map, usually a power of 2
# Out:
# Approximate resolution at NSIDE 32 is 1.8 deg

# %%
NPIX = hp.nside2npix(NSIDE)
print(NPIX)

#NPIX gives the number of pixels of the map
# Out:
# 12288

# %%
m = np.arange(NPIX)
hp.mollview(m, title="Mollview image RING")
hp.graticule()

#RING configuration of the ordering of pixels 
#graticule provides the grid lines, however doesnt work at the moment.
#RING ordering is needed for the spherical harmonic transforms.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-821dd53d03b9> in <module>
#       1 m = np.arange(NPIX)
# ----> 2 hp.mollview(m, title="Mollview image RING")
#       3 hp.graticule()
#
# ~/.local/lib/python3.7/site-packages/healpy/visufunc.py in mollview(map, fig, rot, coord, unit, xsize, title, nest, min, max, flip, remove_dip, remove_mono, gal_cut, format, format2, cbar, cmap, badcolor, bgcolor, notext, norm, hold, reuse_axes, margins, sub, nlocs, return_projected_map, alpha)
#     288                     boundaries=b,
#     289                     values=v,
# --> 290                     format=format,
#     291                 )
#     292             else:
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2127                              'panchor']
#    2128         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2129         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2130
#    2131         self.sca(current_ax)
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1564         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1565     else:
# -> 1566         cb = Colorbar(cax, mappable, **kwargs)
#    1567
#    1568     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, **kw)
#    1070         # Ensure the given mappable's norm has appropriate vmin and vmax set
#    1071         # even if mappable.draw has not yet been called.
# -> 1072         mappable.autoscale_None()
#    1073
#    1074         self.mappable = mappable
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/cm.py in autoscale_None(self)
#     372         """
#     373         if self._A is None:
# --> 374             raise TypeError('You must first set_array for mappable')
#     375         self.norm.autoscale_None(self._A)
#     376         self.changed()
#
# TypeError: You must first set_array for mappable

# %%
vec = hp.ang2vec(np.pi / 2, np.pi * 3 / 4)
print(vec)

#representing the standard coordinates (colattitude theta and longitude phi) as a vector
# Out:
# [-7.07106781e-01  7.07106781e-01  6.12323400e-17]

# %%
ipix_disc = hp.query_disc(nside=32, vec=vec, radius=np.radians(10))

#finds the indicies of all pixels within 10 degrees of the defined vector point
#and changes the value of the map at that location

# %%
m = np.arange(NPIX)
m[ipix_disc] = m.max()
hp.mollview(m, title="Mollview image RING")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-452adea23307> in <module>
#       1 m = np.arange(NPIX)
#       2 m[ipix_disc] = m.max()
# ----> 3 hp.mollview(m, title="Mollview image RING")
#
# ~/.local/lib/python3.7/site-packages/healpy/visufunc.py in mollview(map, fig, rot, coord, unit, xsize, title, nest, min, max, flip, remove_dip, remove_mono, gal_cut, format, format2, cbar, cmap, badcolor, bgcolor, notext, norm, hold, reuse_axes, margins, sub, nlocs, return_projected_map, alpha)
#     288                     boundaries=b,
#     289                     values=v,
# --> 290                     format=format,
#     291                 )
#     292             else:
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2127                              'panchor']
#    2128         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2129         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2130
#    2131         self.sca(current_ax)
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1564         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1565     else:
# -> 1566         cb = Colorbar(cax, mappable, **kwargs)
#    1567
#    1568     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, **kw)
#    1070         # Ensure the given mappable's norm has appropriate vmin and vmax set
#    1071         # even if mappable.draw has not yet been called.
# -> 1072         mappable.autoscale_None()
#    1073
#    1074         self.mappable = mappable
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/cm.py in autoscale_None(self)
#     372         """
#     373         if self._A is None:
# --> 374             raise TypeError('You must first set_array for mappable')
#     375         self.norm.autoscale_None(self._A)
#     376         self.changed()
#
# TypeError: You must first set_array for mappable

# %%
theta, phi = np.degrees(hp.pix2ang(nside=32, ipix=[0, 1, 2, 3, 4]))

#pix2ang retrieves the colattitude and longtidue of each pixel

# %%
theta
# Out:
# array([1.46197116, 1.46197116, 1.46197116, 1.46197116, 2.92418036])

# %%
phi
# Out:
# array([ 45. , 135. , 225. , 315. ,  22.5])

# %%
m = np.arange(NPIX)
hp.mollview(m, nest=True, title="Mollview image Nested")

#NESTED ordering is an efficient way for map operations 
#All healpy routines assume RING ordering, hence why 'nest=True' is required 
#for a NESTED ordering
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-cd3f606f981f> in <module>
#       1 m = np.arange(NPIX)
# ----> 2 hp.mollview(m, nest=True, title="Mollview image Nested")
#       3
#       4 #NESTED ordering is an efficient way for map operations
#       5 #All healpy routines assume RING ordering, hence why 'nest=True' is required
#
# ~/.local/lib/python3.7/site-packages/healpy/visufunc.py in mollview(map, fig, rot, coord, unit, xsize, title, nest, min, max, flip, remove_dip, remove_mono, gal_cut, format, format2, cbar, cmap, badcolor, bgcolor, notext, norm, hold, reuse_axes, margins, sub, nlocs, return_projected_map, alpha)
#     288                     boundaries=b,
#     289                     values=v,
# --> 290                     format=format,
#     291                 )
#     292             else:
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2127                              'panchor']
#    2128         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2129         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2130
#    2131         self.sca(current_ax)
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1564         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1565     else:
# -> 1566         cb = Colorbar(cax, mappable, **kwargs)
#    1567
#    1568     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, **kw)
#    1070         # Ensure the given mappable's norm has appropriate vmin and vmax set
#    1071         # even if mappable.draw has not yet been called.
# -> 1072         mappable.autoscale_None()
#    1073
#    1074         self.mappable = mappable
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/cm.py in autoscale_None(self)
#     372         """
#     373         if self._A is None:
# --> 374             raise TypeError('You must first set_array for mappable')
#     375         self.norm.autoscale_None(self._A)
#     376         self.changed()
#
# TypeError: You must first set_array for mappable

# %%
# !wget -c http://lambda.gsfc.nasa.gov/data/map/dr4/skymaps/7yr/raw/wmap_band_iqumap_r9_7yr_W_v4.fits;wget -c http://lambda.gsfc.nasa.gov/data/map/dr4/ancillary/masks/wmap_temperature_analysis_mask_r9_7yr_v4.fits
# Out:
# --2021-07-21 12:55:15--  http://lambda.gsfc.nasa.gov/data/map/dr4/skymaps/7yr/raw/wmap_band_iqumap_r9_7yr_W_v4.fits
# Resolving lambda.gsfc.nasa.gov (lambda.gsfc.nasa.gov)... 129.164.179.68, 2001:4d0:2310:150::68
# Connecting to lambda.gsfc.nasa.gov (lambda.gsfc.nasa.gov)|129.164.179.68|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://lambda.gsfc.nasa.gov/data/map/dr4/skymaps/7yr/raw/wmap_band_iqumap_r9_7yr_W_v4.fits [following]
# --2021-07-21 12:55:15--  https://lambda.gsfc.nasa.gov/data/map/dr4/skymaps/7yr/raw/wmap_band_iqumap_r9_7yr_W_v4.fits
# Connecting to lambda.gsfc.nasa.gov (lambda.gsfc.nasa.gov)|129.164.179.68|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# --2021-07-21 12:55:16--  http://lambda.gsfc.nasa.gov/data/map/dr4/ancillary/masks/wmap_temperature_analysis_mask_r9_7yr_v4.fits
# Resolving lambda.gsfc.nasa.gov (lambda.gsfc.nasa.gov)... 129.164.179.68, 2001:4d0:2310:150::68
# Connecting to lambda.gsfc.nasa.gov (lambda.gsfc.nasa.gov)|129.164.179.68|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://lambda.gsfc.nasa.gov/data/map/dr4/ancillary/masks/wmap_temperature_analysis_mask_r9_7yr_v4.fits [following]
# --2021-07-21 12:55:16--  https://lambda.gsfc.nasa.gov/data/map/dr4/ancillary/masks/wmap_temperature_analysis_mask_r9_7yr_v4.fits
# Connecting to lambda.gsfc.nasa.gov (lambda.gsfc.nasa.gov)|129.164.179.68|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.

# %%
wmap_map_I = hp.read_map("wmap_band_iqumap_r9_7yr_W_v4.fits")

#retrieves the WMAP data into current directory

# %%
hp.write_map("my_map.fits", wmap_map_I, overwrite=True)
# Out:
# setting the output map dtype to [dtype('>f4')]

# %%
hp.mollview(
    wmap_map_I,
    coord=["G", "E"],
    title="Histogram equalized Ecliptic",
    unit="mK",
    norm="hist",
    min=-1,
    max=0,
)
hp.graticule()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-fdb2559da08e> in <module>
#       6     norm="hist",
#       7     min=-1,
# ----> 8     max=0,
#       9 )
#      10 hp.graticule()
#
# ~/.local/lib/python3.7/site-packages/healpy/visufunc.py in mollview(map, fig, rot, coord, unit, xsize, title, nest, min, max, flip, remove_dip, remove_mono, gal_cut, format, format2, cbar, cmap, badcolor, bgcolor, notext, norm, hold, reuse_axes, margins, sub, nlocs, return_projected_map, alpha)
#     288                     boundaries=b,
#     289                     values=v,
# --> 290                     format=format,
#     291                 )
#     292             else:
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2127                              'panchor']
#    2128         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2129         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2130
#    2131         self.sca(current_ax)
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1564         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1565     else:
# -> 1566         cb = Colorbar(cax, mappable, **kwargs)
#    1567
#    1568     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, **kw)
#    1070         # Ensure the given mappable's norm has appropriate vmin and vmax set
#    1071         # even if mappable.draw has not yet been called.
# -> 1072         mappable.autoscale_None()
#    1073
#    1074         self.mappable = mappable
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/cm.py in autoscale_None(self)
#     372         """
#     373         if self._A is None:
# --> 374             raise TypeError('You must first set_array for mappable')
#     375         self.norm.autoscale_None(self._A)
#     376         self.changed()
#
# TypeError: You must first set_array for mappable

# %%
hp.gnomview(wmap_map_I, rot=[0, 0.3], title="GnomView", unit="mK", format="%.2g")

#gnomview provieds a gnomonic projection around location specified by rot
#x/ysize changes dimensions of the patch of sky observed

#what does the format argument do??
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-dbd9e686c87c> in <module>
# ----> 1 hp.gnomview(wmap_map_I, rot=[0, 0.3], title="GnomView", unit="mK", format="%.2g")
#
# ~/.local/lib/python3.7/site-packages/healpy/visufunc.py in gnomview(map, fig, rot, coord, unit, xsize, ysize, reso, title, nest, remove_dip, remove_mono, gal_cut, min, max, flip, format, cbar, cmap, badcolor, bgcolor, norm, hold, sub, reuse_axes, margins, notext, return_projected_map, no_plot, alpha)
#     552                     boundaries=b,
#     553                     values=v,
# --> 554                     format=format,
#     555                 )
#     556             else:
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2127                              'panchor']
#    2128         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2129         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2130
#    2131         self.sca(current_ax)
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1564         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1565     else:
# -> 1566         cb = Colorbar(cax, mappable, **kwargs)
#    1567
#    1568     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, **kw)
#    1070         # Ensure the given mappable's norm has appropriate vmin and vmax set
#    1071         # even if mappable.draw has not yet been called.
# -> 1072         mappable.autoscale_None()
#    1073
#    1074         self.mappable = mappable
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/cm.py in autoscale_None(self)
#     372         """
#     373         if self._A is None:
# --> 374             raise TypeError('You must first set_array for mappable')
#     375         self.norm.autoscale_None(self._A)
#     376         self.changed()
#
# TypeError: You must first set_array for mappable

# %%
mask = hp.read_map("wmap_temperature_analysis_mask_r9_7yr_v4.fits").astype(np.bool_)
wmap_map_I_masked = hp.ma(wmap_map_I)
wmap_map_I_masked.mask = np.logical_not(mask)

#adds the temperature mask to the map, by convention the mask is 0 where
#the data are masked.
#Filling the masked array fills in the unseen values and returns a standard
#array that can be used as a mollweide projection

# %%
hp.mollview(wmap_map_I_masked.filled())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-895d7b3e9b21> in <module>
# ----> 1 hp.mollview(wmap_map_I_masked.filled())
#
# ~/.local/lib/python3.7/site-packages/healpy/visufunc.py in mollview(map, fig, rot, coord, unit, xsize, title, nest, min, max, flip, remove_dip, remove_mono, gal_cut, format, format2, cbar, cmap, badcolor, bgcolor, notext, norm, hold, reuse_axes, margins, sub, nlocs, return_projected_map, alpha)
#     288                     boundaries=b,
#     289                     values=v,
# --> 290                     format=format,
#     291                 )
#     292             else:
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2127                              'panchor']
#    2128         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2129         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2130
#    2131         self.sca(current_ax)
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1564         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1565     else:
# -> 1566         cb = Colorbar(cax, mappable, **kwargs)
#    1567
#    1568     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, **kw)
#    1070         # Ensure the given mappable's norm has appropriate vmin and vmax set
#    1071         # even if mappable.draw has not yet been called.
# -> 1072         mappable.autoscale_None()
#    1073
#    1074         self.mappable = mappable
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/cm.py in autoscale_None(self)
#     372         """
#     373         if self._A is None:
# --> 374             raise TypeError('You must first set_array for mappable')
#     375         self.norm.autoscale_None(self._A)
#     376         self.changed()
#
# TypeError: You must first set_array for mappable

# %%
plt.hist(wmap_map_I_masked.compressed(), bins=1000);

#compressed() removes the masked pixels and returns a standard array that can
#be used by matplotlib as a histogram function

# %%
LMAX = 1024
cl = hp.anafast(wmap_map_I_masked.filled(), lmax=LMAX)
ell = np.arange(len(cl))

#hp.anafast is a nice tool for computing angular power spectra from maps

# %%
plt.figure(figsize=(10, 5))
plt.plot(ell, ell * (ell+1) * cl)
plt.xlabel("$\ell$")
plt.ylabel("$\ell(\ell+1)C_{\ell}$")
plt.grid()
hp.write_cl("cl.fits", cl, overwrite=True)

#plots a normalised CMB spectrum and writes the file to disk

# %%
wmap_map_I_smoothed = hp.smoothing(wmap_map_I, fwhm=np.radians(1.))
hp.mollview(wmap_map_I_smoothed, min=-1, max=1, title="Map smoothed 1 deg")

#hp.smoothing is the function that smooths the Gaussian beam map
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-ba5a4a7486a7> in <module>
#       1 wmap_map_I_smoothed = hp.smoothing(wmap_map_I, fwhm=np.radians(1.))
# ----> 2 hp.mollview(wmap_map_I_smoothed, min=-1, max=1, title="Map smoothed 1 deg")
#
# ~/.local/lib/python3.7/site-packages/healpy/visufunc.py in mollview(map, fig, rot, coord, unit, xsize, title, nest, min, max, flip, remove_dip, remove_mono, gal_cut, format, format2, cbar, cmap, badcolor, bgcolor, notext, norm, hold, reuse_axes, margins, sub, nlocs, return_projected_map, alpha)
#     288                     boundaries=b,
#     289                     values=v,
# --> 290                     format=format,
#     291                 )
#     292             else:
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2127                              'panchor']
#    2128         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2129         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2130
#    2131         self.sca(current_ax)
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1564         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1565     else:
# -> 1566         cb = Colorbar(cax, mappable, **kwargs)
#    1567
#    1568     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, **kw)
#    1070         # Ensure the given mappable's norm has appropriate vmin and vmax set
#    1071         # even if mappable.draw has not yet been called.
# -> 1072         mappable.autoscale_None()
#    1073
#    1074         self.mappable = mappable
#
# /share/apps/anaconda/3-2019.03/lib/python3.7/site-packages/matplotlib/cm.py in autoscale_None(self)
#     372         """
#     373         if self._A is None:
# --> 374             raise TypeError('You must first set_array for mappable')
#     375         self.norm.autoscale_None(self._A)
#     376         self.changed()
#
# TypeError: You must first set_array for mappable
